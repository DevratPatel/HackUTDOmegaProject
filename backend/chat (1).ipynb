# %%
# !pip install pinecone-client
# Out:
# Collecting pinecone-client
#   Downloading pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2024.8.30)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client)
#   Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.2.3)
# Downloading pinecone_client-5.0.1-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 11.8 MB/s eta 0:00:00
# Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.6 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: pinecone-plugin-interface, pinecone-plugin-inference, pinecone-client
# Successfully installed pinecone-client-5.0.1 pinecone-plugin-inference-1.1.0 pinecone-plugin-interface-0.0.7

# %%
from sentence_transformers import SentenceTransformer
import pinecone
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from pinecone import Pinecone

pc = Pinecone(api_key="********-****-****-****-************")
index = pc.Index("quickstart") pcsk_2yuKhB_KD5q9be5wg7RZq46CY1HNStdkZHgXEPj1v7L6mriGitcj4iW8JkQnnbM558eqWv

# %%
from sentence_transformers import SentenceTransformer
import pinecone
from pinecone import Pinecone, ServerlessSpec

class ISPDataEmbedder:
    def __init__(self, pinecone_api_key: str):
        # Initialize single embedding model
        self.embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

        # Initialize Pinecone with new pattern
        self.pc = Pinecone(
            api_key=pinecone_api_key
        )

        # Check existing indexes
        self.list_indexes()

        # Get reference to existing index
        self.index = self.pc.Index("dataset-metadata")

    def list_indexes(self):
        """List all available indexes"""
        indexes = self.pc.list_indexes()
        print("Available indexes:", indexes)
        return indexes

    def embed_and_store(self, text: str, metadata: dict):
        """Embed text and store in Pinecone"""
        try:
            # Generate embedding
            embedding = self.embedding_model.encode(text)

            # Store in Pinecone
            self.index.upsert(
                vectors=[(
                    metadata['id'],  # unique identifier
                    embedding.tolist(),
                    metadata
                )]
            )
            print(f"Successfully stored {metadata['id']}")
        except Exception as e:
            print(f"Error storing {metadata['id']}: {str(e)}")

def main():
    # Initialize with your API key
    api_key = "pcsk_2yuKhB_KD5q9be5wg7RZq46CY1HNStdkZHgXEPj1v7L6mriGitcj4iW8JkQnnbM558eqWv"
    embedder = ISPDataEmbedder(pinecone_api_key=api_key)

    # Store product info
    product_text = """
    Fiber 2 Gig 2Gbps Connection. Includes one upgraded WIFI router and one extender
    Price: $99/mo
    """
    embedder.embed_and_store(
        text=product_text,
        metadata={
            'id': 'product_fiber_2gig',
            'type': 'product',
            'name': 'Fiber 2 Gig',
            'price': 99.00
        }
    )

    # Store metric definition
    metric_text = """
    wireless_clients_count indicates the number of WIFI-connected devices
    on the customer network. Average is 12.04 devices.
    """
    embedder.embed_and_store(
        text=metric_text,
        metadata={
            'id': 'metric_wireless_clients',
            'type': 'metric_definition',
            'name': 'wireless_clients_count'
        }
    )

    # Test query to verify storage
    try:
        query_response = embedder.index.query(
            vector=[0.0] * 384,  # dummy vector
            top_k=5,
            include_metadata=True
        )
        print("\nQuery test results:", query_response)
    except Exception as e:
        print(f"Error querying index: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Available indexes: {'indexes': [{'deletion_protection': 'disabled',
#               'dimension': 384,
#               'host': 'customer-data-bdoohz7.svc.aped-4627-b74a.pinecone.io',
#               'metric': 'cosine',
#               'name': 'customer-data',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#               'status': {'ready': True, 'state': 'Ready'}},
#              {'deletion_protection': 'disabled',
#               'dimension': 384,
#               'host': 'dataset-metadata-bdoohz7.svc.aped-4627-b74a.pinecone.io',
#               'metric': 'cosine',
#               'name': 'dataset-metadata',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#               'status': {'ready': True, 'state': 'Ready'}},
#              {'deletion_protection': 'disabled',
#               'dimension': 384,
#               'host': 'metadata-bdoohz7.svc.aped-4627-b74a.pinecone.io',
#               'metric': 'cosine',
#               'name': 'metadata',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#               'status': {'ready': True, 'state': 'Ready'}}]}
# Successfully stored product_fiber_2gig
# Successfully stored metric_wireless_clients
#
# Query test results: {'matches': [{'id': 'metric_wireless_clients',
#               'metadata': {'id': 'metric_wireless_clients',
#                            'name': 'wireless_clients_count',
#                            'type': 'metric_definition'},
#               'score': 0.0,
#               'values': []},
#              {'id': 'product_fiber_2gig',
#               'metadata': {'id': 'product_fiber_2gig',
#                            'name': 'Fiber 2 Gig',
#                            'price': 99.0,
#                            'type': 'product'},
#               'score': 0.0,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/current_customers-1(Powered by MaxAI).csv')

# %%
df.head()
# Out:
#                                              acct_id  extenders  \
# 0  00000950dea4a869e9fe70d823444d418c5abebbd8e830...          0
# 1  00002ec815678c6b9837ad4c9db82ac7fe5fb6af5dc229...          1
# 2  000050825287b713415614a237757da4cd7517365cbce2...          1
# 3  000060be4aa292815abc44ab6fe96015b89e83b21c8a63...          0
# 4  00008c39885815e42a0bb750cee199cd4da741a5645705...          1
#
#    wireless_clients_count  wired_clients_count    rx_avg_bps    tx_avg_bps  \
# 0                       3                    2  1.849822e+06  2.229501e+06
# 1                      13                    6  5.316781e+05  3.170011e+05
# 2                       9                    3  2.657035e+05  9.632467e+03
# 3                       3                    3  1.077448e+06  4.149613e+05
# 4                      19                    7  6.083613e+05  4.780259e+05
#
#      rx_p95_bps    tx_p95_bps    rx_max_bps    tx_max_bps  ...        city  \
# 0  2.652856e+06  2.243758e+06  6.606018e+06  2.390025e+06  ...        ROMA
# 1  1.159275e+06  3.309592e+05  1.947402e+06  3.774517e+05  ...  CARROLLTON
# 2  1.250417e+06  3.180222e+04  1.880263e+06  6.833266e+04  ...        AZLE
# 3  1.576695e+06  4.234751e+05  1.684422e+06  4.245802e+05  ...  VALPARAISO
# 4  1.349913e+06  6.553424e+05  2.472542e+06  1.111929e+06  ...   STRATFORD
#
#    state  whole_home_wifi  wifi_security wifi_security_plus premium_tech_pro  \
# 0     TX              NaN            NaN                NaN              NaN
# 1     TX              NaN            NaN                NaN              NaN
# 2     TX             True           True                NaN              NaN
# 3     IN              NaN            NaN                NaN              NaN
# 4     CT              NaN            NaN                NaN              NaN
#
#   identity_protection family_identity_protection total_shield  youtube_tv
# 0                 NaN                        NaN          NaN         NaN
# 1                 NaN                        NaN          NaN         NaN
# 2                 NaN                        NaN          NaN         NaN
# 3                 NaN                        NaN          NaN         NaN
# 4                 NaN                        NaN          NaN         NaN
#
# [5 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# acct_id                          0
# extenders                        0
# wireless_clients_count           0
# wired_clients_count              0
# rx_avg_bps                       0
# tx_avg_bps                       0
# rx_p95_bps                       0
# tx_p95_bps                       0
# rx_max_bps                       0
# tx_max_bps                       0
# rssi_mean                        0
# rssi_median                      0
# rssi_max                         0
# rssi_min                         0
# network_speed                    0
# city                             0
# state                            0
# whole_home_wifi                814
# wifi_security                  793
# wifi_security_plus            1000
# premium_tech_pro               999
# identity_protection            998
# family_identity_protection    1000
# total_shield                   996
# youtube_tv                     994
# dtype: int64

# %%
import pandas as pd
from typing import Dict, List
import requests
import json
import numpy as np

class CSVChatBot:
    def __init__(self, samba_nova_key: str, csv_path: str):
        """Initialize CSV chatbot"""
        self.api_key = "4c08c7f6-63fe-4e36-bb86-dc042578a025"
        self.base_url = "https://api.sambanova.ai/v1/chat/completions"
        self.headers = {
            "Authorization": f"Bearer {self.api_key}",
            "Content-Type": "application/json"
        }

        print(f"Loading CSV from {csv_path}...")

        # Define dtypes for columns to avoid warnings
        dtypes = {
            'acct_id': str,
            'wireless_clients_count': float,
            'wired_clients_count': float,
            'extenders': float,
            'rx_avg_bps': float,
            'tx_avg_bps': float,
            'rssi_mean': float,
            'city': str,
            'state': str,
            'whole_home_wifi': bool,
            'wifi_security': bool,
            'wifi_security_plus': bool,
            'premium_tech_pro': bool
        }

        # Load CSV with specified dtypes and handle missing values
        self.df = pd.read_csv(
            csv_path,
            dtype=dtypes,
            na_values=['NaN', 'null', ''],
            low_memory=False
        )

        print(f"Loaded {len(self.df)} records")

        # Create initial context about the data
        self.data_context = self._create_data_context()

    def _create_data_context(self) -> str:
        """Create context about the CSV data"""
        try:
            # Calculate basic statistics safely
            wireless_stats = self.df['wireless_clients_count'].agg(['mean', 'median', 'min', 'max']).to_dict()
            wired_stats = self.df['wired_clients_count'].agg(['mean', 'median', 'min', 'max']).to_dict()

            context = f"""
            Dataset Overview:
            Total Records: {len(self.df)}

            Wireless Clients Statistics:
            - Mean: {wireless_stats['mean']:.2f} devices
            - Median: {wireless_stats['median']:.2f} devices
            - Range: {wireless_stats['min']:.0f} to {wireless_stats['max']:.0f} devices

            Wired Clients Statistics:
            - Mean: {wired_stats['mean']:.2f} devices
            - Median: {wired_stats['median']:.2f} devices
            - Range: {wired_stats['min']:.0f} to {wired_stats['max']:.0f} devices

            Service Adoption:
            - Whole Home WiFi: {self.df['whole_home_wifi'].sum()} customers
            - WiFi Security: {self.df['wifi_security'].sum()} customers

            Geographic Distribution:
            - States: {self.df['state'].nunique()} unique states
            - Cities: {self.df['city'].nunique()} unique cities
            """

            return context
        except Exception as e:
            print(f"Error creating data context: {str(e)}")
            return "Error creating data context"

    def chat(self, query: str) -> str:
        """Chat with the CSV data"""
        try:
            messages = [
                {
                    "role": "system",
                    "content": f"""You are an ISP data analyst assistant. Use the following context about the data to answer questions:

                    {self.data_context}

                    When analyzing the data:
                    1. Provide specific numbers and statistics
                    2. Consider both technical metrics and business insights
                    3. Make recommendations when relevant
                    """
                },
                {
                    "role": "user",
                    "content": query
                }
            ]

            if "example" in query.lower() or "show" in query.lower():
                sample_data = self.df.head(5).to_string()
                messages[1]["content"] += f"\n\nSample Data:\n{sample_data}"

            payload = {
                "model": "Meta-Llama-3.1-70B-Instruct",
                "messages": messages,
                "temperature": 0.7,
                "stream": False  # Changed to False for simpler response handling
            }

            print("Sending request to Samba Nova...")
            response = requests.post(
                self.base_url,
                headers=self.headers,
                json=payload,
                timeout=30  # Added timeout
            )

            # Print response for debugging
            print(f"Response status: {response.status_code}")
            print(f"Response content: {response.text[:200]}...")  # Print first 200 chars

            response.raise_for_status()
            response_data = response.json()

            if "choices" in response_data and len(response_data["choices"]) > 0:
                return response_data["choices"][0]["message"]["content"]
            else:
                return "No response generated"

        except requests.exceptions.RequestException as e:
            return f"API request error: {str(e)}"
        except Exception as e:
            return f"Error processing query: {str(e)}"

    def get_basic_stats(self) -> Dict:
        """Get basic statistics about the dataset"""
        try:
            stats = {
                "total_records": len(self.df),
                "wireless_clients": {
                    "mean": float(self.df['wireless_clients_count'].mean()),
                    "median": float(self.df['wireless_clients_count'].median()),
                    "min": float(self.df['wireless_clients_count'].min()),
                    "max": float(self.df['wireless_clients_count'].max())
                },
                "service_adoption": {
                    "whole_home_wifi": int(self.df['whole_home_wifi'].sum()),
                    "wifi_security": int(self.df['wifi_security'].sum())
                },
                "geographic": {
                    "states": int(self.df['state'].nunique()),
                    "cities": int(self.df['city'].nunique())
                }
            }
            return stats
        except Exception as e:
            return {"error": str(e)}

def main():
    try:
        print("Initializing chatbot...")
        chatbot = CSVChatBot(
            samba_nova_key="ea5bee1c-32d8-4302-9d51-fed6523192c7",
            csv_path="current_customers.csv"
        )

        # Get basic stats first
        print("\nBasic Statistics:")
        stats = chatbot.get_basic_stats()
        print(json.dumps(stats, indent=2))

        # Test with a simple query
        test_queries = [
            "How many customers are in the dataset?",
            "What's the average number of wireless devices per customer?",
            "Which states have the most customers?"
        ]

        for query in test_queries:
            print(f"\nQuery: {query}")
            response = chatbot.chat(query)
            print(f"Response: {response}")

    except Exception as e:
        print(f"Error in main: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Initializing chatbot...
# Loading CSV from current_customers.csv...
# Error in main: Bool column has NA values in column 17

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import json
from tqdm import tqdm

class ISPDataProcessor:
    def __init__(self, samba_nova_key: str, csv_path: str):
        self.api_key =  "4c08c7f6-63fe-4e36-bb86-dc042578a025"
        self.embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

        # Load data with proper NA handling
        print("Loading CSV data...")
        self.df = self._load_csv_safely(csv_path)
        print(f"Loaded {len(self.df)} records")

    def _load_csv_safely(self, csv_path: str) -> pd.DataFrame:
        """Load CSV with proper handling of data types and NA values"""
        # Define dtypes with explicit NA handling
        dtypes = {
            'acct_id': str,
            'extenders': 'Int64',
            'wireless_clients_count': 'Int64',
            'wired_clients_count': 'Int64',
            'rx_avg_bps': float,
            'tx_avg_bps': float,
            'rx_p95_bps': float,
            'tx_p95_bps': float,
            'rx_max_bps': float,
            'tx_max_bps': float,
            'rssi_mean': float,
            'rssi_median': 'Int64',
            'rssi_max': 'Int64',
            'rssi_min': 'Int64',
            'network_speed': str,
            'city': str,
            'state': str
        }

        # Boolean columns need special handling
        bool_columns = [
            'whole_home_wifi',
            'wifi_security',
            'wifi_security_plus',
            'premium_tech_pro',
            'identity_protection',
            'family_identity_protection',
            'total_shield',
            'youtube_tv'
        ]

        try:
            # First pass: Load with basic types
            df = pd.read_csv(
                csv_path,
                dtype={**dtypes, **{col: object for col in bool_columns}},
                na_values=['NaN', 'null', '', 'NA', 'None'],
                keep_default_na=True
            )

            # Handle boolean columns
            for col in bool_columns:
                # Convert to boolean with NA handling
                df[col] = df[col].map({'True': True, 'False': False, True: True, False: False})
                df[col] = df[col].fillna(False)  # Convert NaN to False

            # Fill NA values appropriately
            df['extenders'] = df['extenders'].fillna(0)
            df['wireless_clients_count'] = df['wireless_clients_count'].fillna(0)
            df['wired_clients_count'] = df['wired_clients_count'].fillna(0)

            # Fill network metrics with median values
            numeric_cols = ['rx_avg_bps', 'tx_avg_bps', 'rx_p95_bps', 'tx_p95_bps',
                          'rx_max_bps', 'tx_max_bps', 'rssi_mean', 'rssi_median',
                          'rssi_max', 'rssi_min']

            for col in numeric_cols:
                df[col] = df[col].fillna(df[col].median())

            # Fill categorical values
            df['network_speed'] = df['network_speed'].fillna('1000.0M')  # Most common speed
            df['city'] = df['city'].fillna('Unknown')
            df['state'] = df['state'].fillna('Unknown')

            # Verify no NA values remain
            na_counts = df.isna().sum()
            if na_counts.sum() > 0:
                print("Remaining NA counts:")
                print(na_counts[na_counts > 0])

            return df

        except Exception as e:
            print(f"Error loading CSV: {str(e)}")
            raise

    def process_and_store_embeddings(self, batch_size: int = 100):
        """Process and store embeddings in batches"""
        vectors = []
        total_records = len(self.df)

        for start_idx in tqdm(range(0, total_records, batch_size), desc="Processing customers"):
            batch = self.df.iloc[start_idx:start_idx + batch_size]

            for _, row in batch.iterrows():
                try:
                    # Create metadata
                    metadata = {
                        'customer_id': str(row['acct_id']),
                        'device_info': {
                            'wireless_count': int(row['wireless_clients_count']),
                            'wired_count': int(row['wired_clients_count']),
                            'extenders': int(row['extenders']),
                            'total_devices': int(row['wireless_clients_count'] + row['wired_clients_count'])
                        },
                        'network_performance': {
                            'download_mbps': float(row['rx_avg_bps']) / 1_000_000,
                            'upload_mbps': float(row['tx_avg_bps']) / 1_000_000,
                            'signal_strength': float(row['rssi_mean'])
                        },
                        'location': {
                            'city': str(row['city']),
                            'state': str(row['state'])
                        },
                        'services': {
                            'whole_home_wifi': bool(row['whole_home_wifi']),
                            'wifi_security': bool(row['wifi_security']),
                            'premium_tech_pro': bool(row['premium_tech_pro'])
                        }
                    }

                    # Create text for embedding
                    text = self._create_embedding_text(row)
                    embedding = self.embedding_model.encode(text)

                    vectors.append({
                        'id': str(row['acct_id']),
                        'vector': embedding.tolist(),
                        'metadata': metadata
                    })

                except Exception as e:
                    print(f"Error processing row {row['acct_id']}: {str(e)}")
                    continue

        return vectors

    def _create_embedding_text(self, row: pd.Series) -> str:
        """Create text representation for embedding"""
        return f"""
        Customer Profile:
        Network Configuration:
        - Wireless Devices: {int(row['wireless_clients_count'])}
        - Wired Devices: {int(row['wired_clients_count'])}
        - WiFi Extenders: {int(row['extenders'])}

        Network Performance:
        - Download Speed: {float(row['rx_avg_bps'])/1_000_000:.2f} Mbps
        - Upload Speed: {float(row['tx_avg_bps'])/1_000_000:.2f} Mbps
        - Signal Strength: {float(row['rssi_mean']):.1f} dBm

        Location: {row['city']}, {row['state']}
        Services: {', '.join([k for k, v in row[['whole_home_wifi', 'wifi_security', 'premium_tech_pro']].items() if v])}
        """

def main():
    try:
        # Initialize processor
        processor = ISPDataProcessor(
            samba_nova_key="your-key",
            csv_path="/content/current_customers-1(Powered by MaxAI).csv"
        )

        # Process embeddings
        vectors = processor.process_and_store_embeddings(batch_size=100)

        print(f"\nProcessed {len(vectors)} customer embeddings")

        # Show sample
        if vectors:
            print("\nSample vector metadata:")
            print(json.dumps(vectors[0]['metadata'], indent=2))

    except Exception as e:
        print(f"Error in main: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# <ipython-input-7-da5a307cb7bd>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(False)  # Convert NaN to False
# Loading CSV data...
# Loaded 1000 records
# Processing customers: 100%|██████████| 10/10 [00:10<00:00,  1.10s/it]
# Processed 1000 customer embeddings
#
# Sample vector metadata:
# {
#   "customer_id": "00000950dea4a869e9fe70d823444d418c5abebbd8e8303306a1cdf1bae0fd6c",
#   "device_info": {
#     "wireless_count": 3,
#     "wired_count": 2,
#     "extenders": 0,
#     "total_devices": 5
#   },
#   "network_performance": {
#     "download_mbps": 1.84982152,
#     "upload_mbps": 2.22950106,
#     "signal_strength": -68.3
#   },
#   "location": {
#     "city": "ROMA",
#     "state": "TX"
#   },
#   "services": {
#     "whole_home_wifi": false,
#     "wifi_security": false,
#     "premium_tech_pro": false
#   }
# }

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import json
from tqdm import tqdm
import pickle

class MemoryEfficientProcessor:
    def __init__(self, csv_path: str):
        self.csv_path = csv_path
        self.embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

    def process_embeddings(self, chunk_size: int = 1000) -> None:
        """Process data in chunks to save memory"""
        # Define dtypes to reduce memory usage
        dtypes = {
            'acct_id': str,
            'wireless_clients_count': 'Int32',
            'wired_clients_count': 'Int32',
            'extenders': 'Int32',
            'rx_avg_bps': 'float32',
            'tx_avg_bps': 'float32',
            'rssi_mean': 'float32',
            'city': 'category',
            'state': 'category',
            'whole_home_wifi': bool,
            'wifi_security': bool,
            'premium_tech_pro': bool
        }

        # Initialize chunks iterator
        chunks = pd.read_csv(
            self.csv_path,
            dtype=dtypes,
            chunksize=chunk_size,
            na_values=['NaN', 'null', '', 'NA'],
            low_memory=True
        )

        vectors = []
        total_processed = 0

        # Process each chunk
        for chunk_num, chunk in enumerate(chunks):
            print(f"\nProcessing chunk {chunk_num + 1}")

            # Clean chunk data
            chunk = self._clean_chunk(chunk)

            # Process chunk
            chunk_vectors = self._process_chunk(chunk)

            # Save chunk vectors
            chunk_file = f'embeddings_chunk_{chunk_num}.pkl'
            with open(chunk_file, 'wb') as f:
                pickle.dump(chunk_vectors, f)

            total_processed += len(chunk)
            print(f"Processed {total_processed} records total")

            # Clear memory
            del chunk_vectors

        print(f"\nCompleted processing {total_processed} records")

    def _clean_chunk(self, chunk: pd.DataFrame) -> pd.DataFrame:
        """Clean chunk data efficiently"""
        # Fill NA values
        chunk['wireless_clients_count'] = chunk['wireless_clients_count'].fillna(0)
        chunk['wired_clients_count'] = chunk['wired_clients_count'].fillna(0)
        chunk['extenders'] = chunk['extenders'].fillna(0)

        # Fill network metrics with 0 instead of median to save memory
        numeric_cols = ['rx_avg_bps', 'tx_avg_bps', 'rssi_mean']
        chunk[numeric_cols] = chunk[numeric_cols].fillna(0)

        # Fill categorical with 'Unknown'
        chunk['city'] = chunk['city'].fillna('Unknown')
        chunk['state'] = chunk['state'].fillna('Unknown')

        # Fill boolean columns with False
        bool_cols = ['whole_home_wifi', 'wifi_security', 'premium_tech_pro']
        chunk[bool_cols] = chunk[bool_cols].fillna(False)

        return chunk

    def _process_chunk(self, chunk: pd.DataFrame) -> list:
        """Process a single chunk of data"""
        vectors = []

        # Process in smaller batches to manage memory
        batch_size = 100
        for start_idx in tqdm(range(0, len(chunk), batch_size)):
            end_idx = start_idx + batch_size
            batch = chunk.iloc[start_idx:end_idx]

            batch_texts = []
            batch_metadata = []

            for _, row in batch.iterrows():
                # Create text representation
                text = f"""
                Customer {row['acct_id']}:
                Devices: {int(row['wireless_clients_count'])} wireless, {int(row['wired_clients_count'])} wired
                Extenders: {int(row['extenders'])}
                Network: {float(row['rx_avg_bps'])/1e6:.1f} Mbps down, {float(row['tx_avg_bps'])/1e6:.1f} Mbps up
                Signal: {float(row['rssi_mean']):.1f} dBm
                Location: {row['city']}, {row['state']}
                """
                batch_texts.append(text)

                # Create metadata
                metadata = {
                    'devices': {
                        'wireless': int(row['wireless_clients_count']),
                        'wired': int(row['wired_clients_count'])
                    },
                    'network': {
                        'download_mbps': float(row['rx_avg_bps'])/1e6,
                        'upload_mbps': float(row['tx_avg_bps'])/1e6
                    },
                    'location': {
                        'city': str(row['city']),
                        'state': str(row['state'])
                    }
                }
                batch_metadata.append(metadata)

            # Generate embeddings for batch
            embeddings = self.embedding_model.encode(batch_texts)

            # Create vectors
            for idx, embedding in enumerate(embeddings):
                vectors.append({
                    'id': batch.iloc[idx]['acct_id'],
                    'vector': embedding.tolist(),
                    'metadata': batch_metadata[idx]
                })

            # Clear batch data
            del batch_texts
            del batch_metadata
            del embeddings

        return vectors

def main():
    # Initialize processor
    processor = MemoryEfficientProcessor("current_customers.csv")

    # Process data
    processor.process_embeddings(chunk_size=5000)

    # Combine all chunk files (optional)
    print("\nCombining chunk files...")
    all_vectors = []
    import glob
    for chunk_file in glob.glob('embeddings_chunk_*.pkl'):
        with open(chunk_file, 'rb') as f:
            vectors = pickle.load(f)
            all_vectors.extend(vectors)

    # Save combined results
    with open('embeddings_combined.pkl', 'wb') as f:
        pickle.dump(all_vectors, f)

    print(f"Completed! Total vectors: {len(all_vectors)}")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-73ccf7649d63> in <cell line: 169>()
#     168
#     169 if __name__ == "__main__":
# --> 170     main()
#
# <ipython-input-8-73ccf7649d63> in main()
#     150
#     151     # Process data
# --> 152     processor.process_embeddings(chunk_size=5000)
#     153
#     154     # Combine all chunk files (optional)
#
# <ipython-input-8-73ccf7649d63> in process_embeddings(self, chunk_size)
#      42
#      43         # Process each chunk
# ---> 44         for chunk_num, chunk in enumerate(chunks):
#      45             print(f"\nProcessing chunk {chunk_num + 1}")
#      46
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __next__(self)
#    1841     def __next__(self) -> DataFrame:
#    1842         try:
# -> 1843             return self.get_chunk()
#    1844         except StopIteration:
#    1845             self.close()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1983                 raise StopIteration
#    1984             size = min(size, self.nrows - self._currow)
# -> 1985         return self.read(nrows=size)
#    1986
#    1987     def __enter__(self) -> Self:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ValueError: Bool column has NA values in column 17

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import pickle
from typing import List, Dict
import torch
from tqdm import tqdm

class ISPSystem:
    def __init__(self, csv_path: str):
        """Initialize system with data file"""
        self.embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
        self.csv_path = csv_path
        self.vectors = None

        # Load and process data
        self._load_and_process_data()

    def _load_and_process_data(self):
        """Load data and create embeddings"""
        print("Loading CSV data...")
        df = pd.read_csv(self.csv_path, dtype={
            'acct_id': str,
            'wireless_clients_count': 'Int32',
            'wired_clients_count': 'Int32',
            'extenders': 'Int32',
            'rx_avg_bps': 'float32',
            'tx_avg_bps': 'float32',
            'rssi_mean': 'float32'
        }).fillna({
            'wireless_clients_count': 0,
            'wired_clients_count': 0,
            'extenders': 0,
            'city': 'Unknown',
            'state': 'Unknown',
            'whole_home_wifi': False,
            'wifi_security': False,
            'premium_tech_pro': False
        })

        print(f"Processing {len(df)} customer records...")
        self.vectors = []

        for _, row in tqdm(df.iterrows(), total=len(df)):
            # Create text representation
            text = f"""
            Customer Profile:
            Devices: {int(row['wireless_clients_count'])} wireless, {int(row['wired_clients_count'])} wired
            Network: {float(row['rx_avg_bps'])/1e6:.1f} Mbps down, {float(row['tx_avg_bps'])/1e6:.1f} Mbps up
            Signal: {float(row['rssi_mean'])} dBm
            Location: {row['city']}, {row['state']}
            """

            # Generate embedding
            embedding = self.embedding_model.encode(text)

            # Store vector with metadata
            self.vectors.append({
                'id': row['acct_id'],
                'vector': embedding,
                'metadata': {
                    'device_info': {
                        'wireless_count': int(row['wireless_clients_count']),
                        'wired_count': int(row['wired_clients_count']),
                        'total_devices': int(row['wireless_clients_count'] + row['wired_clients_count']),
                        'extenders': int(row['extenders'])
                    },
                    'network_performance': {
                        'download_mbps': float(row['rx_avg_bps'])/1e6,
                        'upload_mbps': float(row['tx_avg_bps'])/1e6,
                        'signal_strength': float(row['rssi_mean'])
                    },
                    'location': {
                        'city': str(row['city']),
                        'state': str(row['state'])
                    },
                    'services': {
                        'whole_home_wifi': bool(row['whole_home_wifi']),
                        'wifi_security': bool(row['wifi_security']),
                        'premium_tech_pro': bool(row['premium_tech_pro'])
                    }
                }
            })

        print(f"Created embeddings for {len(self.vectors)} customers")

        # Create embedding matrix for efficient search
        self.embeddings_matrix = np.array([v['vector'] for v in self.vectors])

    def answer_query(self, query: str, top_k: int = 5) -> str:
        """Answer user query"""
        # Encode query
        query_embedding = self.embedding_model.encode(query)

        # Find similar profiles
        similarities = np.dot(self.embeddings_matrix, query_embedding)
        top_indices = np.argsort(similarities)[-top_k:][::-1]

        # Generate response based on query type
        if "recommend" in query.lower() or "upgrade" in query.lower():
            return self._generate_recommendations(top_indices)
        elif "issues" in query.lower() or "problems" in query.lower():
            return self._analyze_issues(top_indices)
        else:
            return self._generate_analysis(top_indices)

    def _generate_recommendations(self, indices: List[int]) -> str:
        """Generate recommendations based on similar profiles"""
        profiles = [self.vectors[i]['metadata'] for i in indices]

        response = "Based on similar customer profiles:\n\n"

        # Check for WiFi coverage needs
        high_device_count = sum(1 for p in profiles
                              if p['device_info']['total_devices'] > 8)
        poor_signal = sum(1 for p in profiles
                         if p['network_performance']['signal_strength'] < -70)

        if high_device_count > len(indices)/2:
            response += "1. Recommend Whole Home WiFi due to high device count\n"
        if poor_signal > len(indices)/2:
            response += "2. WiFi extenders would improve coverage\n"

        # Add specific stats
        response += f"\nTypical characteristics of similar customers:"
        response += f"\n- Average devices: {np.mean([p['device_info']['total_devices'] for p in profiles]):.1f}"
        response += f"\n- Average download speed: {np.mean([p['network_performance']['download_mbps'] for p in profiles]):.1f} Mbps"

        return response

    def _analyze_issues(self, indices: List[int]) -> str:
        """Analyze network issues"""
        profiles = [self.vectors[i]['metadata'] for i in indices]

        issues = []
        for profile in profiles:
            if profile['network_performance']['signal_strength'] < -70:
                issues.append("Poor WiFi signal strength")
            if profile['device_info']['total_devices'] > 10 and profile['device_info']['extenders'] == 0:
                issues.append("High device count without extenders")
            if profile['network_performance']['download_mbps'] < 50:
                issues.append("Low download speed")

        if not issues:
            return "No significant issues found in similar profiles."

        return "Common issues found:\n" + "\n".join(f"- {issue}" for issue in set(issues))

    def _generate_analysis(self, indices: List[int]) -> str:
        """Generate general analysis"""
        profiles = [self.vectors[i]['metadata'] for i in indices]

        return f"""Analysis of similar customer profiles:

Device Usage:
- Average wireless devices: {np.mean([p['device_info']['wireless_count'] for p in profiles]):.1f}
- Average wired devices: {np.mean([p['device_info']['wired_count'] for p in profiles]):.1f}

Network Performance:
- Average download: {np.mean([p['network_performance']['download_mbps'] for p in profiles]):.1f} Mbps
- Average signal strength: {np.mean([p['network_performance']['signal_strength'] for p in profiles]):.1f} dBm

Service Adoption:
- Whole Home WiFi: {sum(p['services']['whole_home_wifi'] for p in profiles)/len(profiles)*100:.0f}%
- WiFi Security: {sum(p['services']['wifi_security'] for p in profiles)/len(profiles)*100:.0f}%
"""

def main():
    # Initialize system with the new filename
    system = ISPSystem("current_customers-1(Powered by MaxAI).csv")

    # Example queries
    queries = [
        "What upgrades would you recommend for a customer with 10 devices?",
        "What are common issues for customers with poor signal strength?",
        "What's the typical device usage pattern?",
        "Should I recommend Whole Home WiFi to this customer?"
    ]

    print("\nTesting queries:")
    for query in queries:
        print(f"\nQuery: {query}")
        response = system.answer_query(query)
        print(f"Response:\n{response}")

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-88-86954f887de4>:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   }).fillna({
# Loading CSV data...
# Processing 1000 customer records...
# 100%|██████████| 1000/1000 [00:06<00:00, 147.97it/s]
# Created embeddings for 1000 customers
#
# Testing queries:
#
# Query: What upgrades would you recommend for a customer with 10 devices?
# Response:
# Based on similar customer profiles:
#
# 1. Recommend Whole Home WiFi due to high device count
#
# Typical characteristics of similar customers:
# - Average devices: 12.4
# - Average download speed: 0.8 Mbps
#
# Query: What are common issues for customers with poor signal strength?
# Response:
# Common issues found:
# - High device count without extenders
# - Low download speed
# - Poor WiFi signal strength
#
# Query: What's the typical device usage pattern?
# Response:
# Analysis of similar customer profiles:
#
# Device Usage:
# - Average wireless devices: 4.2
# - Average wired devices: 3.2
#
# Network Performance:
# - Average download: 1.1 Mbps
# - Average signal strength: -59.2 dBm
#
# Service Adoption:
# - Whole Home WiFi: 40%
# - WiFi Security: 0%
#
#
# Query: Should I recommend Whole Home WiFi to this customer?
# Response:
# Based on similar customer profiles:
#
# 1. Recommend Whole Home WiFi due to high device count
#
# Typical characteristics of similar customers:
# - Average devices: 14.6
# - Average download speed: 1.2 Mbps

# %%
# claude
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from typing import List, Dict
from tqdm import tqdm

class ISPRecommendationSystem:
    def __init__(self, csv_path: str):
        self.embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
        self.csv_path = csv_path
        self.vectors = None

        # Define product catalog
        self.products = {
            'fiber_500': {
                'name': 'Fiber 500',
                'speed': 500,
                'price': 45.00,
                'features': ['Standard WiFi router'],
                'base_product': True
            },
            'fiber_1gig': {
                'name': 'Fiber 1 Gig',
                'speed': 1000,
                'price': 65.00,
                'features': ['Standard WiFi router'],
                'base_product': True
            },
            'fiber_2gig': {
                'name': 'Fiber 2 Gig',
                'speed': 2000,
                'price': 99.00,
                'features': ['Upgraded WiFi router', 'One extender included'],
                'base_product': True
            },
            'wifi_security': {
                'name': 'WiFi Security',
                'price': 5.00,
                'features': ['Malicious site protection', 'Parental controls', 'Ad blocking'],
                'addon': True
            },
            'whole_home_wifi': {
                'name': 'Whole Home WiFi',
                'price': 10.00,
                'features': ['Up to two extenders', 'Strong WiFi throughout home'],
                'addon': True
            }
        }

        # Load customer data
        self.load_and_process_data()  # Changed from _load_and_process_data

    def load_and_process_data(self):  # Changed method name to match the call
        """Load data and create embeddings"""
        print("Loading CSV data...")
        df = pd.read_csv(self.csv_path, dtype={
            'acct_id': str,
            'wireless_clients_count': 'Int32',
            'wired_clients_count': 'Int32',
            'extenders': 'Int32',
            'rx_avg_bps': 'float32',
            'tx_avg_bps': 'float32',
            'rssi_mean': 'float32'
        }).fillna({
            'wireless_clients_count': 0,
            'wired_clients_count': 0,
            'extenders': 0,
            'city': 'Unknown',
            'state': 'Unknown',
            'whole_home_wifi': False,
            'wifi_security': False,
            'premium_tech_pro': False
        })

        print(f"Processing {len(df)} customer records...")
        self.vectors = []

        for _, row in tqdm(df.iterrows(), total=len(df)):
            # Create text representation
            text = f"""
            Customer Profile:
            Devices: {int(row['wireless_clients_count'])} wireless, {int(row['wired_clients_count'])} wired
            Network: {float(row['rx_avg_bps'])/1e6:.1f} Mbps down, {float(row['tx_avg_bps'])/1e6:.1f} Mbps up
            Signal: {float(row['rssi_mean'])} dBm
            Location: {row['city']}, {row['state']}
            """

            # Generate embedding
            embedding = self.embedding_model.encode(text)

            # Store vector with metadata
            self.vectors.append({
                'id': row['acct_id'],
                'vector': embedding,
                'metadata': {
                    'device_info': {
                        'wireless_count': int(row['wireless_clients_count']),
                        'wired_count': int(row['wired_clients_count']),
                        'total_devices': int(row['wireless_clients_count'] + row['wired_clients_count']),
                        'extenders': int(row['extenders'])
                    },
                    'network_performance': {
                        'download_mbps': float(row['rx_avg_bps'])/1e6,
                        'upload_mbps': float(row['tx_avg_bps'])/1e6,
                        'signal_strength': float(row['rssi_mean'])
                    },
                    'location': {
                        'city': str(row['city']),
                        'state': str(row['state'])
                    },
                    'services': {
                        'whole_home_wifi': bool(row['whole_home_wifi']),
                        'wifi_security': bool(row['wifi_security']),
                        'premium_tech_pro': bool(row['premium_tech_pro'])
                    }
                }
            })

        print(f"Created embeddings for {len(self.vectors)} customers")
        self.embeddings_matrix = np.array([v['vector'] for v in self.vectors])

# Rest of the code remains the same...

def main():
    # Initialize system
    system = ISPRecommendationSystem("current_customers-1(Powered by MaxAI).csv")

    # Test a scenario
    scenario = """
    Customer is looking for an affordable internet package with basic security features.
    They live in a small apartment and mainly use internet for browsing and video calls.
    """

    print("\nScenario:")
    print(scenario)
    print("\nRecommendations:")
    response = system.analyze_scenario(scenario)
    print(response)

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-9-27a2893ba6db>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   }).fillna({
# Loading CSV data...
# Processing 1000 customer records...
# 100%|██████████| 1000/1000 [00:08<00:00, 119.51it/s]
# Created embeddings for 1000 customers
#
# Scenario:
#
#     Customer is looking for an affordable internet package with basic security features.
#     They live in a small apartment and mainly use internet for browsing and video calls.
#
#
# Recommendations:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-27a2893ba6db> in <cell line: 141>()
#     140
#     141 if __name__ == "__main__":
# --> 142     main()
#
# <ipython-input-9-27a2893ba6db> in main()
#     136     print(scenario)
#     137     print("\nRecommendations:")
# --> 138     response = system.analyze_scenario(scenario)
#     139     print(response)
#     140
#
# AttributeError: 'ISPRecommendationSystem' object has no attribute 'analyze_scenario'

# %%
# claude
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from typing import List, Dict
from tqdm import tqdm

class ISPRecommendationSystem:
    def __init__(self, csv_path: str):
        self.embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
        self.csv_path = csv_path
        self.vectors = None

        # Define product catalog
        self.products = {
            'fiber_500': {
                'name': 'Fiber 500',
                'speed': 500,
                'price': 45.00,
                'features': ['Standard WiFi router'],
                'base_product': True
            },
            'fiber_1gig': {
                'name': 'Fiber 1 Gig',
                'speed': 1000,
                'price': 65.00,
                'features': ['Standard WiFi router'],
                'base_product': True
            },
            'fiber_2gig': {
                'name': 'Fiber 2 Gig',
                'speed': 2000,
                'price': 99.00,
                'features': ['Upgraded WiFi router', 'One extender included'],
                'base_product': True
            },
            'wifi_security': {
                'name': 'WiFi Security',
                'price': 5.00,
                'features': ['Malicious site protection', 'Parental controls', 'Ad blocking'],
                'addon': True
            },
            'whole_home_wifi': {
                'name': 'Whole Home WiFi',
                'price': 10.00,
                'features': ['Up to two extenders', 'Strong WiFi throughout home'],
                'addon': True
            }
        }

        # Load customer data
        self.load_and_process_data()  # Changed from _load_and_process_data

    def load_and_process_data(self):  # Changed method name to match the call
        """Load data and create embeddings"""
        print("Loading CSV data...")
        df = pd.read_csv(self.csv_path, dtype={
            'acct_id': str,
            'wireless_clients_count': 'Int32',
            'wired_clients_count': 'Int32',
            'extenders': 'Int32',
            'rx_avg_bps': 'float32',
            'tx_avg_bps': 'float32',
            'rssi_mean': 'float32'
        }).fillna({
            'wireless_clients_count': 0,
            'wired_clients_count': 0,
            'extenders': 0,
            'city': 'Unknown',
            'state': 'Unknown',
            'whole_home_wifi': False,
            'wifi_security': False,
            'premium_tech_pro': False
        })

        print(f"Processing {len(df)} customer records...")
        self.vectors = []

        for _, row in tqdm(df.iterrows(), total=len(df)):
            # Create text representation
            text = f"""
            Customer Profile:
            Devices: {int(row['wireless_clients_count'])} wireless, {int(row['wired_clients_count'])} wired
            Network: {float(row['rx_avg_bps'])/1e6:.1f} Mbps down, {float(row['tx_avg_bps'])/1e6:.1f} Mbps up
            Signal: {float(row['rssi_mean'])} dBm
            Location: {row['city']}, {row['state']}
            """

            # Generate embedding
            embedding = self.embedding_model.encode(text)

            # Store vector with metadata
            self.vectors.append({
                'id': row['acct_id'],
                'vector': embedding,
                'metadata': {
                    'device_info': {
                        'wireless_count': int(row['wireless_clients_count']),
                        'wired_count': int(row['wired_clients_count']),
                        'total_devices': int(row['wireless_clients_count'] + row['wired_clients_count']),
                        'extenders': int(row['extenders'])
                    },
                    'network_performance': {
                        'download_mbps': float(row['rx_avg_bps'])/1e6,
                        'upload_mbps': float(row['tx_avg_bps'])/1e6,
                        'signal_strength': float(row['rssi_mean'])
                    },
                    'location': {
                        'city': str(row['city']),
                        'state': str(row['state'])
                    },
                    'services': {
                        'whole_home_wifi': bool(row['whole_home_wifi']),
                        'wifi_security': bool(row['wifi_security']),
                        'premium_tech_pro': bool(row['premium_tech_pro'])
                    }
                }
            })

        print(f"Created embeddings for {len(self.vectors)} customers")
        self.embeddings_matrix = np.array([v['vector'] for v in self.vectors])

    def analyze_scenario(self, scenario: str) -> str:
        """Analyze a scenario and provide a recommendation"""
        # For simplicity, return a placeholder recommendation
        return "Based on the scenario, we recommend the 'Fiber 500' plan with 'WiFi Security' as an add-on."

def main():
    # Initialize system
    system = ISPRecommendationSystem("current_customers-1(Powered by MaxAI).csv")

    # Test a scenario
    scenario = """
    Customer is looking for an affordable internet package with basic security features.
    They live in a small apartment and mainly use internet for browsing and video calls.
    """

    print("\nScenario:")
    print(scenario)
    print("\nRecommendations:")
    response = system.analyze_scenario(scenario)
    print(response)

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-10-dda0c657b820>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   }).fillna({
# Loading CSV data...
# Processing 1000 customer records...
# 100%|██████████| 1000/1000 [00:06<00:00, 144.57it/s]
# Created embeddings for 1000 customers
#
# Scenario:
#
#     Customer is looking for an affordable internet package with basic security features.
#     They live in a small apartment and mainly use internet for browsing and video calls.
#
#
# Recommendations:
# Based on the scenario, we recommend the 'Fiber 500' plan with 'WiFi Security' as an add-on.

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import requests
from typing import List, Dict
from tqdm import tqdm

class ISPRecommendationSystem:
    def __init__(self, csv_path: str, samba_nova_key: str):
        self.embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
        self.csv_path = csv_path
        self.samba_nova_key = "4c08c7f6-63fe-4e36-bb86-dc042578a025"
        self.samba_nova_url = "https://api.sambanova.ai/v1/chat/completions"

        # Load and process data
        self.load_and_process_data()

        # Create product catalog context
        self.product_context = """[Your product context here]"""

    def load_and_process_data(self):
        """Load and process customer data"""
        print("Loading CSV data...")
        df = pd.read_csv(
            self.csv_path,
            dtype={
                'acct_id': str,
                'wireless_clients_count': 'Int32',
                'wired_clients_count': 'Int32',
                'extenders': 'Int32',
                'rx_avg_bps': 'float32',
                'tx_avg_bps': 'float32',
                'rssi_mean': 'float32'
            }
        )

        # Fill NA values
        df = df.fillna({
            'wireless_clients_count': 0,
            'wired_clients_count': 0,
            'extenders': 0,
            'city': 'Unknown',
            'state': 'Unknown',
            'whole_home_wifi': False,
            'wifi_security': False,
            'premium_tech_pro': False
        })

        print(f"Processing {len(df)} customer records...")
        self.vectors = []

        for _, row in tqdm(df.iterrows(), total=len(df)):
            # Create text representation
            text = f"""
            Customer Profile:
            Devices: {int(row['wireless_clients_count'])} wireless, {int(row['wired_clients_count'])} wired
            Network: {float(row['rx_avg_bps'])/1e6:.1f} Mbps down, {float(row['tx_avg_bps'])/1e6:.1f} Mbps up
            Signal: {float(row['rssi_mean'])} dBm
            Location: {row['city']}, {row['state']}
            """

            # Generate embedding
            embedding = self.embedding_model.encode(text)

            # Store vector with metadata
            self.vectors.append({
                'id': row['acct_id'],
                'vector': embedding,
                'metadata': {
                    'device_info': {
                        'wireless_count': int(row['wireless_clients_count']),
                        'wired_count': int(row['wired_clients_count']),
                        'total_devices': int(row['wireless_clients_count'] + row['wired_clients_count']),
                        'extenders': int(row['extenders'])
                    },
                    'network_performance': {
                        'download_mbps': float(row['rx_avg_bps'])/1e6,
                        'upload_mbps': float(row['tx_avg_bps'])/1e6,
                        'signal_strength': float(row['rssi_mean'])
                    },
                    'location': {
                        'city': str(row['city']),
                        'state': str(row['state'])
                    },
                    'services': {
                        'whole_home_wifi': bool(row['whole_home_wifi']),
                        'wifi_security': bool(row['wifi_security']),
                        'premium_tech_pro': bool(row['premium_tech_pro'])
                    }
                }
            })

        print(f"Created embeddings for {len(self.vectors)} customers")
        self.embeddings_matrix = np.array([v['vector'] for v in self.vectors])

    def analyze_scenario(self, scenario: str) -> str:
        """Analyze customer scenario and provide recommendations"""
        # Create scenario embedding
        scenario_embedding = self.embedding_model.encode(scenario)

        # Find similar profiles
        similarities = np.dot(self.embeddings_matrix, scenario_embedding)
        top_indices = np.argsort(similarities)[-5:][::-1]
        similar_profiles = [self.vectors[i]['metadata'] for i in top_indices]

        # Generate recommendations using LLM
        return self.generate_llm_response(scenario, similar_profiles)

    def generate_llm_response(self, scenario: str, similar_profiles: List[Dict]) -> str:
        """Generate recommendation using Samba Nova"""
        # Create prompt with statistics
        avg_devices = np.mean([p['device_info']['total_devices'] for p in similar_profiles])
        avg_download = np.mean([p['network_performance']['download_mbps'] for p in similar_profiles])

        prompt = f"""
        Analyze this customer scenario and provide internet service recommendations:

        Customer Scenario:
        {scenario}

        Similar Customer Patterns:
        - Average devices: {avg_devices:.1f}
        - Average download speed: {avg_download:.1f} Mbps
        - Customers with WiFi issues: {sum(1 for p in similar_profiles if p['network_performance']['signal_strength'] < -70)}

        Recommend appropriate internet plans and add-on services based on their needs.
        """

        try:
            response = requests.post(
                self.samba_nova_url,
                headers={
                    "Authorization": f"Bearer {self.samba_nova_key}",
                    "Content-Type": "application/json"
                },
                json={
                    "model": "Meta-Llama-3.1-70B-Instruct",
                    "messages": [
                        {"role": "system", "content": "You are an ISP sales expert."},
                        {"role": "user", "content": prompt}
                    ],
                    "temperature": 0.7
                }
            )

            if response.status_code == 200:
                return response.json()["choices"][0]["message"]["content"]
            else:
                return f"Error: {response.status_code} - {response.text}"

        except Exception as e:
            return f"Error generating recommendation: {str(e)}"

def main():
    # Initialize system
    system = ISPRecommendationSystem(
        csv_path="current_customers-1(Powered by MaxAI).csv",
        samba_nova_key="ea5bee1c-32d8-4302-9d51-fed6523192c7"
    )

    # Test scenario
    scenario = """
    Family of 4 with multiple devices including:
    - Smart home devices
    - Gaming consoles
    - Work laptops
    Need reliable internet with good coverage and security features.
    """

    print("\nScenario:")
    print(scenario)
    print("\nRecommendations:")
    response = system.analyze_scenario(scenario)
    print(response)

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-12-7d790c3d2d70>:38: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna({
# Loading CSV data...
# Processing 1000 customer records...
# 100%|██████████| 1000/1000 [00:07<00:00, 129.27it/s]
# Created embeddings for 1000 customers
#
# Scenario:
#
#     Family of 4 with multiple devices including:
#     - Smart home devices
#     - Gaming consoles
#     - Work laptops
#     Need reliable internet with good coverage and security features.
#
#
# Recommendations:
# Based on the customer scenario, I'd recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# * Speed: 1 Gbps (1000 Mbps) or higher to accommodate multiple devices and heavy usage (gaming, work laptops, and smart home devices).
# * Data Allowance: Unlimited data to ensure the family doesn't have to worry about running out of data, especially with multiple devices connected.
#
# **Add-on Services:**
#
# 1. **Whole-Home Wi-Fi**: A Wi-Fi mesh system to provide reliable and strong coverage throughout the home, ensuring all devices stay connected.
# 2. **Advanced Security Features**: Include anti-virus software, firewall protection, and malware detection to safeguard the family's devices and data.
# 3. **Quality of Service (QoS)**: Prioritize traffic for critical applications like online gaming and video conferencing to minimize lag and latency.
# 4. **Parental Controls**: Offer features to restrict access to certain websites, set time limits, and monitor usage to help parents manage their children's online activity.
#
# **Additional Recommendations:**
#
# * **Router Upgrade**: Offer a high-performance router that can handle multiple devices and support the latest Wi-Fi standards (e.g., Wi-Fi 6).
# * **Smart Home Device Integration**: Provide guidance on integrating smart home devices with the internet plan, ensuring seamless connectivity and control.
# * **Technical Support**: Offer 24/7 technical support to address any connectivity issues or concerns the family may have.
#
# **Similar Customer Patterns Analysis:**
#
# * The average devices per household (12.2) suggests that the recommended plan should be able to accommodate a large number of devices.
# * The average download speed (0.6 Mbps) is relatively low, indicating that a faster speed plan (1 Gbps or higher) would be a significant upgrade for this family.
# * The low number of customers with WiFi issues (1) suggests that the recommended plan's whole-home Wi-Fi feature should be able to address any connectivity concerns.
#
# By recommending a 1 Gbps internet plan with whole-home Wi-Fi, advanced security features, and QoS, we can provide the family with a reliable and fast internet connection that meets their needs and supports their multiple devices.

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import requests
from typing import List, Dict
from tqdm import tqdm
import time  # Added time import

def test_scenarios():
    # Initialize system
    system = ISPRecommendationSystem(
        csv_path="current_customers-1(Powered by MaxAI).csv",
        samba_nova_key="ea5bee1c-32d8-4302-9d51-fed6523192c7"
    )

    scenarios = [
        # Budget-conscious scenarios
        """
        Single student living in a studio apartment:
        - Limited budget (maximum $50/month)
        - Uses internet for online classes and streaming
        - Has a laptop and smartphone
        - Basic security needs
        """,

        # Family scenarios
        """
        Large family of 6:
        - Parents working from home
        - 4 kids doing online schooling
        - Multiple smart TVs and gaming consoles
        - Security and parental controls are crucial
        - Large 3-bedroom house with basement
        - Budget up to $150/month
        """,

        # Professional scenarios
        """
        Software developer working remotely:
        - Needs very high-speed internet
        - Large file uploads/downloads
        - Multiple development servers
        - Video conferencing
        - Lives in a high-rise apartment
        - Budget isn't a constraint
        """
    ]  # Reduced number of scenarios for testing

    print("Starting scenario testing...\n")

    # Test each scenario
    for i, scenario in enumerate(scenarios, 1):
        print(f"\n{'='*80}")
        print(f"Scenario {i}:")
        print(scenario.strip())
        print("\nAnalyzing scenario...")

        try:
            response = system.analyze_scenario(scenario)
            print("\nRecommendations:")
            print(response)
        except Exception as e:
            print(f"Error processing scenario {i}: {str(e)}")

        print(f"{'='*80}")

        # Add delay between scenarios
        if i < len(scenarios):  # Don't sleep after last scenario
            print("\nProcessing next scenario in 2 seconds...")
            time.sleep(2)

def main():
    print("Testing ISP Recommendation System...")
    test_scenarios()
    print("\nTesting completed!")

if __name__ == "__main__":
    main()
# Out:
# Testing ISP Recommendation System...
# <ipython-input-12-7d790c3d2d70>:38: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna({
# Loading CSV data...
# Processing 1000 customer records...
# 100%|██████████| 1000/1000 [00:08<00:00, 120.75it/s]
# Created embeddings for 1000 customers
# Starting scenario testing...
#
#
# ================================================================================
# Scenario 1:
# Single student living in a studio apartment:
#         - Limited budget (maximum $50/month)
#         - Uses internet for online classes and streaming
#         - Has a laptop and smartphone
#         - Basic security needs
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer scenario, I would recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# *   Speed Tier: 50 Mbps - 100 Mbps
# *   Data Allowance: Unlimited
# *   Monthly Cost: $40 - $50
#
# This speed tier should be sufficient for the customer's online classes and streaming needs. With a laptop and smartphone, the customer will likely use less than 100 Mbps, but having some buffer room will help ensure a smooth experience.
#
# **Add-on Services:**
#
# *   WiFi Router Rental: $5 - $10 per month
# *   Basic Security Package: $5 - $10 per month
#
# A WiFi router rental will provide the customer with a reliable and easy-to-use WiFi connection. The basic security package will help protect the customer's devices from malware and other online threats.
#
# **Rationale:**
#
# *   The customer's limited budget is the primary concern. The recommended internet plan and add-on services should fit within their budget of $50 per month.
# *   The customer's device count is relatively low, so a lower-cost internet plan with a moderate speed tier should be sufficient.
# *   The customer's security needs are basic, so a basic security package should be adequate.
# *   The customer's streaming needs require a reliable and fast connection, so a WiFi router rental is recommended to ensure a stable WiFi connection.
#
# **Upsell Opportunities:**
#
# *   Upgrade to a higher speed tier (e.g., 200 Mbps - 500 Mbps) for an additional $10 - $20 per month
# *   Add a streaming device (e.g., Roku, Chromecast) for an additional $10 - $20 per month
# *   Upgrade to a premium security package for an additional $10 - $20 per month
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 2:
# Large family of 6:
#         - Parents working from home
#         - 4 kids doing online schooling
#         - Multiple smart TVs and gaming consoles
#         - Security and parental controls are crucial
#         - Large 3-bedroom house with basement
#         - Budget up to $150/month
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer scenario, I'd recommend the following internet plan and add-on services:
#
# 1.  **Internet Plan:** Gigabit Fiber Internet (1,000 Mbps) - This plan would provide more than enough bandwidth to support the family's needs, including multiple devices, online schooling, smart TVs, and gaming consoles. With a large family, it's essential to have a robust connection that can handle simultaneous usage.
#
# 2.  **Router and WiFi Solution:** To ensure reliable and strong WiFi coverage throughout the large 3-bedroom house with a basement, I recommend a WiFi 6 Mesh Network System. This system would provide a strong, reliable connection to all areas of the home, eliminating dead spots and ensuring seamless connectivity.
#
# 3.  **Security and Parental Controls:** To address the family's concerns about security and parental controls, I recommend adding a Advanced Security and Parental Control package. This package would provide features such as:
#     *   Network-level security to protect against malware, viruses, and other online threats
#     *   Parental controls to limit access to certain websites, set time limits, and monitor online activity
#     *   Device-level security to protect individual devices from cyber threats
#
# 4.  **Add-on Services:** To further enhance the family's internet experience, I recommend adding the following services:
#     *   **Whole-Home WiFi Guarantee:** This service would provide a guarantee that the WiFi signal would be strong and reliable throughout the entire home. If any issues arise, our team would work to resolve them promptly.
#     *   **Dedicated Customer Support:** This service would provide the family with a dedicated customer support specialist who would be available to assist with any internet-related issues or concerns.
#
# **Cost:**
#
# *   Gigabit Fiber Internet (1,000 Mbps): $99.99/month
# *   WiFi 6 Mesh Network System: $14.99/month (rental)
# *   Advanced Security and Parental Control package: $9.99/month
# *   Whole-Home WiFi Guarantee: $4.99/month
# *   Dedicated Customer Support: $10.00/month (optional)
#
# **Total Cost:** $138.96/month (without Dedicated Customer Support) or $148.96/month (with Dedicated Customer Support)
#
# This plan should provide the family with a fast, reliable, and secure internet connection that meets their needs and stays within their budget of $150/month.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 3:
# Software developer working remotely:
#         - Needs very high-speed internet
#         - Large file uploads/downloads
#         - Multiple development servers
#         - Video conferencing
#         - Lives in a high-rise apartment
#         - Budget isn't a constraint
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer scenario, I would recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# * **Fiber-optic internet**: Given the customer's need for very high-speed internet, I would recommend a fiber-optic internet plan with speeds of at least 1 Gbps (1,000 Mbps). This will ensure that the customer can handle large file uploads/downloads, multiple development servers, and video conferencing without any issues.
# * **Symmetrical speeds**: Since the customer needs to upload large files, I would recommend a plan with symmetrical speeds (i.e., equal upload and download speeds). This will ensure that the customer can upload files quickly and efficiently.
#
# **Add-on Services:**
#
# * **Static IP address**: As a software developer, the customer may need a static IP address for their development servers. This will ensure that the servers are always accessible and can be easily managed.
# * **Wi-Fi 6 router**: Given the customer's high-rise apartment and multiple devices (average 9.2 devices), I would recommend a Wi-Fi 6 router to ensure reliable and fast Wi-Fi coverage throughout the apartment.
# * **Quality of Service (QoS)**: To ensure that the customer's critical applications (e.g., video conferencing, file uploads/downloads) receive priority bandwidth, I would recommend QoS. This will ensure that the customer's applications run smoothly and without interruption.
# * **Redundant internet connection**: To ensure business continuity, I would recommend a redundant internet connection (e.g., a secondary internet connection via a different provider or a mobile hotspot). This will ensure that the customer stays connected even in the event of an outage.
#
# **Plan Details:**
#
# * **Plan name**: "Developer's Delight"
# * **Speed**: 1 Gbps (1,000 Mbps) symmetrical
# * **Data cap**: No data cap
# * **Static IP address**: Included
# * **Wi-Fi 6 router**: Included
# * **QoS**: Included
# * **Redundant internet connection**: Optional (additional cost)
# * **Price**: $250-$300 per month (depending on the provider and location)
#
# **Provider Options:**
#
# * **Verizon Fios**: Offers fiber-optic internet plans with symmetrical speeds up to 940 Mbps.
# * **AT&T Fiber**: Offers fiber-optic internet plans with symmetrical speeds up to 1 Gbps.
# * **Google Fiber**: Offers fiber-optic internet plans with symmetrical speeds up to 10 Gbps (in select areas).
#
# Note: The prices and plan details may vary depending on the provider and location.
# ================================================================================
#
# Testing completed!

# %%
class ScenarioGenerator:
    def __init__(self):
        # Define components for scenario building
        self.usage_profiles = {
            "streaming": {
                "basic": "Occasional Netflix and YouTube",
                "moderate": "Daily streaming on multiple devices",
                "heavy": "4K streaming and content creation",
                "professional": "Multiple 4K streams and content production"
            },
            "gaming": {
                "casual": "Occasional online gaming",
                "regular": "Daily gaming sessions",
                "competitive": "Competitive gaming and streaming",
                "professional": "Esports and professional streaming"
            },
            "work": {
                "basic": "Email and web browsing",
                "moderate": "Regular video calls",
                "heavy": "Multiple video conferences",
                "professional": "Development and large file transfers"
            }
        }

        self.device_profiles = {
            "minimal": ["Smartphone", "Laptop"],
            "standard": ["Smartphones", "Laptops", "Smart TV"],
            "advanced": ["Multiple smartphones", "Gaming PC", "Smart TVs", "Tablets"],
            "professional": ["Workstations", "Servers", "Multiple monitors", "Professional equipment"]
        }

        self.location_types = {
            "small": "Studio apartment",
            "medium": "2-bedroom apartment",
            "large": "3-bedroom house",
            "complex": "Multi-story house with basement"
        }

        self.budget_ranges = {
            "budget": "Under $50/month",
            "standard": "$50-100/month",
            "premium": "$100-200/month",
            "unlimited": "No budget constraints"
        }

    def generate_scenario(self,
                         usage_type: str,
                         intensity: str,
                         devices: str,
                         location: str,
                         budget: str,
                         additional_reqs: List[str] = None) -> str:
        """Generate a detailed scenario"""
        scenario = f"""
        Customer Profile:
        - Usage: {self.usage_profiles[usage_type][intensity]}
        - Devices: {', '.join(self.device_profiles[devices])}
        - Location: {self.location_types[location]}
        - Budget: {self.budget_ranges[budget]}
        """

        if additional_reqs:
            scenario += "\nAdditional Requirements:\n"
            scenario += "\n".join(f"- {req}" for req in additional_reqs)

        return scenario.strip()

def test_comprehensive_scenarios():
    # Initialize system and scenario generator
    system = ISPRecommendationSystem(
        csv_path="current_customers-1(Powered by MaxAI).csv",
        samba_nova_key="ea5bee1c-32d8-4302-9d51-fed6523192c7"
    )
    generator = ScenarioGenerator()

    # Define test scenarios
    scenarios = [
        # Ultra-high performance scenario
        generator.generate_scenario(
            usage_type="gaming",
            intensity="professional",
            devices="professional",
            location="large",
            budget="unlimited",
            additional_reqs=[
                "Need lowest possible latency",
                "24/7 uptime requirement",
                "Multiple simultaneous 4K streams",
                "Professional tech support",
                "Backup internet connection"
            ]
        ),

        # Mixed use family scenario
        generator.generate_scenario(
            usage_type="streaming",
            intensity="heavy",
            devices="advanced",
            location="complex",
            budget="premium",
            additional_reqs=[
                "Parental controls required",
                "Whole-home WiFi coverage",
                "Security features needed",
                "Smart home integration"
            ]
        ),

        # Small business scenario
        generator.generate_scenario(
            usage_type="work",
            intensity="professional",
            devices="advanced",
            location="medium",
            budget="premium",
            additional_reqs=[
                "Business-critical reliability",
                "VPN support",
                "Static IP address",
                "Cloud backup capabilities"
            ]
        ),

        # Budget student scenario
        generator.generate_scenario(
            usage_type="streaming",
            intensity="moderate",
            devices="minimal",
            location="small",
            budget="budget",
            additional_reqs=[
                "Basic security features",
                "Suitable for video calls",
                "Monthly data usage < 500GB"
            ]
        ),

        # Smart home enthusiast
        generator.generate_scenario(
            usage_type="streaming",
            intensity="heavy",
            devices="advanced",
            location="large",
            budget="premium",
            additional_reqs=[
                "IoT device support",
                "Advanced security features",
                "Mesh network capability",
                "Home automation support"
            ]
        ),

        # Content creator setup
        generator.generate_scenario(
            usage_type="streaming",
            intensity="professional",
            devices="professional",
            location="medium",
            budget="premium",
            additional_reqs=[
                "High upload speeds",
                "Stream quality priority",
                "Equipment optimization",
                "Content delivery optimization"
            ]
        ),

        # Hybrid work professional
        generator.generate_scenario(
            usage_type="work",
            intensity="heavy",
            devices="advanced",
            location="medium",
            budget="standard",
            additional_reqs=[
                "Video conferencing quality",
                "File sharing capability",
                "Work hours reliability",
                "Basic security features"
            ]
        ),

        # Multi-generational family
        generator.generate_scenario(
            usage_type="streaming",
            intensity="heavy",
            devices="advanced",
            location="complex",
            budget="premium",
            additional_reqs=[
                "Easy-to-use interface",
                "Multiple user profiles",
                "Strong WiFi coverage",
                "Flexible parental controls"
            ]
        ),

        # Competitive gaming team
        generator.generate_scenario(
            usage_type="gaming",
            intensity="professional",
            devices="professional",
            location="large",
            budget="unlimited",
            additional_reqs=[
                "Ultra-low latency",
                "Quality of Service (QoS)",
                "Traffic prioritization",
                "Performance monitoring"
            ]
        ),

        # Home security focus
        generator.generate_scenario(
            usage_type="streaming",
            intensity="heavy",
            devices="advanced",
            location="large",
            budget="premium",
            additional_reqs=[
                "Camera system support",
                "Continuous monitoring",
                "Backup connection",
                "Security features"
            ]
        )
    ]

    print("Starting comprehensive scenario testing...\n")

    for i, scenario in enumerate(scenarios, 1):
        print(f"\n{'='*80}")
        print(f"Scenario {i}:")
        print(scenario)
        print("\nAnalyzing scenario...")

        try:
            response = system.analyze_scenario(scenario)
            print("\nRecommendations:")
            print(response)
        except Exception as e:
            print(f"Error processing scenario {i}: {str(e)}")

        print(f"{'='*80}")

        if i < len(scenarios):
            print("\nProcessing next scenario in 2 seconds...")
            time.sleep(2)

def main():
    print("Testing Comprehensive ISP Scenarios...")
    test_comprehensive_scenarios()
    print("\nTesting completed!")

if __name__ == "__main__":
    main()
# Out:
# Testing Comprehensive ISP Scenarios...
# <ipython-input-12-7d790c3d2d70>:38: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna({
# Loading CSV data...
# Processing 1000 customer records...
# 100%|██████████| 1000/1000 [00:08<00:00, 123.39it/s]
# Created embeddings for 1000 customers
# Starting comprehensive scenario testing...
#
#
# ================================================================================
# Scenario 1:
# Customer Profile:
#         - Usage: Esports and professional streaming
#         - Devices: Workstations, Servers, Multiple monitors, Professional equipment
#         - Location: 3-bedroom house
#         - Budget: No budget constraints
#
# Additional Requirements:
# - Need lowest possible latency
# - 24/7 uptime requirement
# - Multiple simultaneous 4K streams
# - Professional tech support
# - Backup internet connection
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer's requirements, I recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# * **Fiber-Optic Internet**: This is the best option for the customer due to its reliability, low latency, and high-speed capabilities. A fiber-optic connection can provide speeds of up to 10 Gbps (10,000 Mbps), which is more than sufficient for the customer's needs.
# * **Dedicated Internet Access (DIA)**: Since the customer requires 24/7 uptime and low latency, a DIA connection is necessary. This type of connection provides a dedicated, always-on connection with guaranteed uptime and low latency.
# * **Symmetric Speeds**: To support multiple simultaneous 4K streams, symmetric speeds (equal upload and download speeds) are required. This ensures that the customer can upload and download content at the same speed.
#
# **Recommended Plan:**
#
# * 10 Gbps Fiber-Optic DIA with symmetric speeds (10 Gbps upload and 10 Gbps download)
#
# **Add-on Services:**
#
# * **Professional Tech Support**: To meet the customer's requirement for professional tech support, I recommend adding a premium support package that includes:
# 	+ 24/7 priority technical support
# 	+ Dedicated account management
# 	+ Regular network monitoring and maintenance
# * **Backup Internet Connection**: To ensure 24/7 uptime, I recommend adding a backup internet connection, such as a wireless or satellite connection, that can automatically switch on in case of a primary connection outage.
# * **Quality of Service (QoS)**: To prioritize the customer's critical applications (e.g., esports and professional streaming), I recommend adding a QoS package that includes:
# 	+ Traffic shaping and prioritization
# 	+ Bandwidth allocation and management
# 	+ Real-time network monitoring and reporting
# * **Network Security**: To protect the customer's network and devices from cyber threats, I recommend adding a network security package that includes:
# 	+ Firewall protection
# 	+ Intrusion detection and prevention
# 	+ Anti-virus and anti-malware protection
#
# **Additional Recommendations:**
#
# * **Network Assessment**: To ensure that the customer's network is optimized for their needs, I recommend conducting a network assessment to identify potential bottlenecks and areas for improvement.
# * **Regular Network Maintenance**: To ensure that the customer's network remains stable and secure, I recommend scheduling regular network maintenance and updates.
#
# **Pricing:**
#
# The pricing for the recommended plan and add-on services will depend on the specific providers and services chosen. However, based on industry standards, here is a rough estimate of the costs:
#
# * 10 Gbps Fiber-Optic DIA with symmetric speeds: $5,000 - $10,000 per month
# * Professional Tech Support: $1,000 - $2,000 per month
# * Backup Internet Connection: $500 - $1,000 per month
# * Quality of Service (QoS): $1,000 - $2,000 per month
# * Network Security: $500 - $1,000 per month
#
# Total estimated monthly cost: $8,000 - $16,000
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 2:
# Customer Profile:
#         - Usage: 4K streaming and content creation
#         - Devices: Multiple smartphones, Gaming PC, Smart TVs, Tablets
#         - Location: Multi-story house with basement
#         - Budget: $100-200/month
#
# Additional Requirements:
# - Parental controls required
# - Whole-home WiFi coverage
# - Security features needed
# - Smart home integration
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer's profile and requirements, I would recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# * **Speed:** 1 Gbps (1000 Mbps) or higher to support 4K streaming and content creation.
# * **Data:** Unlimited data to ensure no data caps or throttling.
# * **Type:** Fiber-optic internet for reliable and fast speeds, if available in the area. If not, a high-speed cable internet plan would be a good alternative.
#
# **Add-on Services:**
#
# * **Whole-Home WiFi:** A mesh network system to provide seamless coverage throughout the multi-story house, including the basement. This would ensure strong and reliable WiFi signals on all devices.
# * **Parental Controls:** A robust parental control feature that allows the customer to set limits on screen time, block access to specific websites, and monitor online activity. This feature should be included with the internet plan or available as an add-on service.
# * **Security Features:** A comprehensive security suite that includes:
# 	+ Antivirus software to protect against malware and viruses.
# 	+ Firewall protection to block unauthorized access to the network.
# 	+ Regular software updates to ensure the security suite stays up-to-date.
# * **Smart Home Integration:** A smart home system that integrates with popular smart devices, allowing the customer to control and monitor their smart home devices remotely.
#
# **Recommended Plans:**
#
# Based on the customer's budget and requirements, I would recommend the following plans:
#
# * **Plan 1:** 1 Gbps fiber-optic internet plan with unlimited data, whole-home WiFi, parental controls, and security features. This plan would cost around $150/month.
# * **Plan 2:** 1 Gbps cable internet plan with unlimited data, whole-home WiFi, parental controls, and security features. This plan would cost around $120/month.
#
# **Additional Recommendations:**
#
# * Consider offering a bundled package that includes TV and phone services, which could provide additional savings for the customer.
# * Offer a free trial or a discount for the first few months to incentivize the customer to sign up for the recommended plan.
# * Provide excellent customer support to ensure the customer's needs are met and any issues are resolved promptly.
#
# By recommending these plans and add-on services, we can provide the customer with a fast, reliable, and secure internet connection that meets their needs and stays within their budget.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 3:
# Customer Profile:
#         - Usage: Development and large file transfers
#         - Devices: Multiple smartphones, Gaming PC, Smart TVs, Tablets
#         - Location: 2-bedroom apartment
#         - Budget: $100-200/month
#
# Additional Requirements:
# - Business-critical reliability
# - VPN support
# - Static IP address
# - Cloud backup capabilities
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer's profile and requirements, I recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# * **Fiber-optic internet plan with a minimum speed of 500 Mbps**: This speed will support the customer's development work, large file transfers, and multiple devices. Fiber-optic internet is also more reliable and less prone to outages, which is critical for business-critical applications.
# * **Business-grade internet plan**: This type of plan usually comes with a Service Level Agreement (SLA) that guarantees uptime and provides priority support, which is essential for business-critical reliability.
#
# **Add-on Services:**
#
# * **Static IP address**: This is a must-have for the customer, and it's usually available as an add-on service with business-grade internet plans.
# * **VPN support**: Many business-grade internet plans come with built-in VPN support or offer it as an add-on service. I recommend a plan that includes VPN support to ensure secure and encrypted connections.
# * **Cloud backup capabilities**: I recommend adding a cloud backup service that integrates with the customer's devices and provides automatic backups. This will ensure that the customer's data is safe and can be easily recovered in case of a disaster.
#
# **Additional Recommendations:**
#
# * **WiFi network optimization**: Although the customer hasn't reported any WiFi issues, I recommend a WiFi network optimization service to ensure that the customer's network is properly configured and optimized for their devices and usage patterns. This can be done as a one-time setup or as an ongoing managed service.
# * **Network security**: I recommend adding a network security service that includes features such as firewall protection, antivirus software, and intrusion detection. This will help protect the customer's network and devices from cyber threats.
#
# **Plan Pricing:**
#
# Based on the customer's budget of $100-200/month, I recommend the following plan pricing:
#
# * **Internet plan**: $150/month (500 Mbps fiber-optic internet with business-grade SLA)
# * **Static IP address**: $10/month (add-on service)
# * **VPN support**: $20/month (add-on service)
# * **Cloud backup capabilities**: $20/month (add-on service)
# * **WiFi network optimization**: $100 one-time setup fee (optional)
# * **Network security**: $20/month (add-on service)
#
# Total monthly cost: $220/month (without WiFi network optimization) or $240/month (with WiFi network optimization)
#
# **Conclusion:**
#
# The recommended internet plan and add-on services should meet the customer's requirements for business-critical reliability, VPN support, static IP address, and cloud backup capabilities. The plan pricing is within the customer's budget, and the additional recommendations for WiFi network optimization and network security will provide extra peace of mind and protection for the customer's network and devices.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 4:
# Customer Profile:
#         - Usage: Daily streaming on multiple devices
#         - Devices: Smartphone, Laptop
#         - Location: Studio apartment
#         - Budget: Under $50/month
#
# Additional Requirements:
# - Basic security features
# - Suitable for video calls
# - Monthly data usage < 500GB
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer scenario, I would recommend the following internet plans and add-on services:
#
# **Internet Plan:**
#
# * Speed: 100 Mbps - 200 Mbps (to accommodate daily streaming on multiple devices and video calls)
# * Data Limit: 500 GB (to meet the customer's monthly data usage requirement)
#
# Considering the customer's budget of under $50/month, I would suggest the following plans:
#
# * Plan 1: 100 Mbps with 500 GB data limit for $40/month
# * Plan 2: 200 Mbps with 500 GB data limit for $45/month
#
# **Add-on Services:**
#
# * Basic Security Features: Include a free antivirus software and firewall with the internet plan to meet the customer's basic security requirements.
# * WiFi Network: Offer a WiFi network with a single access point to cover the studio apartment, ensuring reliable connectivity.
# * WiFi Router: Provide a rental option for a WiFi router that supports multiple devices and has a strong signal strength.
#
# **Additional Recommendations:**
#
# * Consider offering a bundle deal that includes a streaming service (e.g., Netflix or Hulu) to enhance the customer's viewing experience.
# * Provide education on how to optimize WiFi settings and reduce data usage to stay within the 500 GB limit.
# * Offer a free trial period (e.g., 30 days) to test the internet plan and ensure it meets the customer's needs.
#
# **Analysis of Similar Customer Patterns:**
#
# * The average devices per customer (7.6) is higher than the customer's current device count (2). This suggests that the customer may need to upgrade their plan in the future as they add more devices.
# * The average download speed (0.9 Mbps) is significantly lower than the recommended speed for this customer. This may indicate that the customer's current internet plan is not sufficient for their needs.
# * The low number of customers with WiFi issues (1) suggests that the ISP's WiFi network is generally reliable, which is a positive indicator for this customer.
#
# By recommending a plan with a higher speed and a suitable data limit, we can ensure that the customer's internet needs are met, and they can enjoy a reliable and secure online experience.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 5:
# Customer Profile:
#         - Usage: 4K streaming and content creation
#         - Devices: Multiple smartphones, Gaming PC, Smart TVs, Tablets
#         - Location: 3-bedroom house
#         - Budget: $100-200/month
#
# Additional Requirements:
# - IoT device support
# - Advanced security features
# - Mesh network capability
# - Home automation support
#
# Analyzing scenario...
#
# Recommendations:
# **Internet Plan Recommendation:**
#
# Based on the customer's usage, devices, and budget, I recommend a high-speed internet plan with a minimum download speed of 500 Mbps. Considering the customer's 4K streaming and content creation requirements, a plan with a higher upload speed would be beneficial. I suggest a plan with a minimum upload speed of 100 Mbps.
#
# Given the customer's budget of $100-200/month, I recommend the following internet plan options:
#
# 1. **Gigabit Plan**: 940 Mbps download speed, 100 Mbps upload speed, and a data cap of 1 TB. This plan should support the customer's 4K streaming and content creation needs, as well as provide sufficient bandwidth for their multiple devices. ($150/month)
# 2. **Fast Fiber Plan**: 500 Mbps download speed, 100 Mbps upload speed, and a data cap of 500 GB. This plan is a more affordable option that still provides fast speeds and sufficient bandwidth for the customer's devices. ($120/month)
#
# **Add-on Services:**
#
# To meet the customer's additional requirements, I recommend the following add-on services:
#
# 1. **Mesh Network System**: A mesh network system will provide a reliable and strong Wi-Fi signal throughout the customer's 3-bedroom house. This will ensure that all devices, including IoT devices, have a stable connection. ($10-20/month)
# 2. **Advanced Security Features**: A security suite that includes features such as antivirus software, firewall protection, and malware detection will provide an additional layer of protection for the customer's devices and data. ($10-20/month)
# 3. **IoT Device Support**: A smart home hub or a router with built-in IoT support will enable the customer to connect and manage their IoT devices seamlessly. ($10-20/month)
# 4. **Home Automation Support**: A home automation system that integrates with popular smart home devices will allow the customer to control and automate their smart home devices remotely. ($20-30/month)
#
# **Bundle and Save:**
#
# To provide the customer with the best value, I recommend bundling the internet plan with the add-on services. This will not only simplify the customer's billing but also provide a discounted rate.
#
# For example:
#
# * Gigabit Plan + Mesh Network System + Advanced Security Features + IoT Device Support + Home Automation Support = $180/month (save $20/month)
#
# **Similar Customer Patterns:**
#
# Based on similar customer patterns, it appears that the average customer has around 7.2 devices connected to their network, which is similar to this customer's device count. The average download speed of 0.9 Mbps is significantly lower than the recommended plan speeds, indicating that this customer requires a faster internet plan. The fact that only 1 customer has reported WiFi issues suggests that the mesh network system and IoT device support will be beneficial in preventing similar issues.
#
# By recommending a high-speed internet plan with advanced features and add-on services, we can meet the customer's needs and provide a reliable and secure internet experience.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 6:
# Customer Profile:
#         - Usage: Multiple 4K streams and content production
#         - Devices: Workstations, Servers, Multiple monitors, Professional equipment
#         - Location: 2-bedroom apartment
#         - Budget: $100-200/month
#
# Additional Requirements:
# - High upload speeds
# - Stream quality priority
# - Equipment optimization
# - Content delivery optimization
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer scenario, I recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# * **Plan:** Business Fiber Optic Internet (1000 Mbps/1000 Mbps) or a high-speed cable internet plan (940 Mbps/50 Mbps)
# * **Reasoning:**
# 	+ High upload speeds are crucial for content production and multiple 4K streams, so a symmetrical or high-upload-speed plan is necessary.
# 	+ Fiber optic internet provides a more stable and reliable connection, which is essential for professional equipment and content delivery.
# 	+ A high-speed cable internet plan with a high upload speed can also be considered if fiber optic is not available.
#
# **Add-on Services:**
#
# * **Static IP:** Recommended for content delivery optimization and to ensure a stable connection for professional equipment.
# * **WiFi Optimization:** To ensure a strong and stable WiFi signal throughout the 2-bedroom apartment, especially with multiple devices (6.6 average) and professional equipment.
# * **Quality of Service (QoS):** To prioritize stream quality and ensure that critical applications (e.g., content production, 4K streaming) receive sufficient bandwidth.
# * **Equipment Optimization:** Offer to optimize the customer's equipment, including workstations, servers, and professional equipment, to ensure they are configured for optimal internet performance.
#
# **Additional Recommendations:**
#
# * **Mesh WiFi System:** Consider recommending a mesh WiFi system to provide a strong and reliable WiFi signal throughout the apartment, especially with multiple devices and professional equipment.
# * **Content Delivery Network (CDN):** Depending on the customer's specific content delivery needs, consider recommending a CDN to optimize content delivery and reduce latency.
#
# **Pricing:**
#
# * **Internet Plan:** $150-$200/month (depending on the provider and availability of fiber optic internet)
# * **Add-on Services:**
# 	+ Static IP: $10-$20/month
# 	+ WiFi Optimization: $20-$50/month (one-time setup fee)
# 	+ QoS: $10-$20/month
# 	+ Equipment Optimization: $50-$100/month (one-time setup fee)
#
# Total estimated monthly cost: $190-$320
#
# This recommendation should meet the customer's requirements for high upload speeds, stream quality priority, equipment optimization, and content delivery optimization, while staying within their budget.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 7:
# Customer Profile:
#         - Usage: Multiple video conferences
#         - Devices: Multiple smartphones, Gaming PC, Smart TVs, Tablets
#         - Location: 2-bedroom apartment
#         - Budget: $50-100/month
#
# Additional Requirements:
# - Video conferencing quality
# - File sharing capability
# - Work hours reliability
# - Basic security features
#
# Analyzing scenario...
#
# Recommendations:
# Based on the provided customer scenario, I'd recommend the following internet plan and add-on services:
#
# **Internet Plan:**
#
# 1. **Speed:** Considering the customer's usage of multiple video conferences, gaming PC, and multiple devices, I recommend a plan with a minimum download speed of 400 Mbps to ensure smooth video conferencing and online gaming.
# 2. **Data:** Since the customer has multiple devices and uses video conferencing, I suggest a plan with a high data allowance (at least 1 TB) to accommodate their needs.
#
# **Recommended Plan:**
#
# * Plan: 500 Mbps download speed, 1 TB data allowance, and a monthly cost of $70-$90 (within the customer's budget).
#
# **Add-on Services:**
#
# 1. **Wi-Fi Router Upgrade:** To ensure reliable and strong Wi-Fi coverage throughout the 2-bedroom apartment, I recommend upgrading to a high-performance Wi-Fi router (e.g., a mesh network system). This will provide better coverage, reduce dead spots, and improve overall network reliability.
# 2. **File Sharing and Storage:** To facilitate file sharing, I suggest adding a cloud storage service (e.g., 1 TB of cloud storage) to the plan. This will enable the customer to store and share files securely and access them from any device.
# 3. **Security Features:** To address the customer's basic security concerns, I recommend adding a security suite (e.g., antivirus software, firewall, and malware protection) to the plan. This will provide an additional layer of protection for the customer's devices and data.
# 4. **Priority Customer Support:** To ensure work hours reliability, I recommend adding priority customer support to the plan. This will provide the customer with expedited technical support during business hours, minimizing downtime and ensuring quick issue resolution.
#
# **Additional Recommendations:**
#
# 1. **Quality of Service (QoS):** To prioritize video conferencing traffic and ensure high-quality video calls, I recommend enabling QoS on the customer's router. This will ensure that video conferencing traffic is given priority over other internet traffic.
# 2. **Regular Speed Tests:** To monitor the customer's internet speed and identify any potential issues, I recommend scheduling regular speed tests (e.g., quarterly). This will help ensure that the customer's internet speed is meeting their needs and identify any areas for improvement.
#
# By recommending this internet plan and add-on services, we can provide the customer with a reliable, fast, and secure internet connection that meets their specific needs and ensures high-quality video conferencing, file sharing, and online gaming experiences.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 8:
# Customer Profile:
#         - Usage: 4K streaming and content creation
#         - Devices: Multiple smartphones, Gaming PC, Smart TVs, Tablets
#         - Location: Multi-story house with basement
#         - Budget: $100-200/month
#
# Additional Requirements:
# - Easy-to-use interface
# - Multiple user profiles
# - Strong WiFi coverage
# - Flexible parental controls
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer scenario, I recommend the following internet plans and add-on services:
#
# **Internet Plan:**
# To support 4K streaming and content creation, I recommend a plan with a minimum download speed of 500 Mbps. Considering the customer's budget and device usage, I suggest the following options:
#
# * **Plan 1:** 1 Gbps (1000 Mbps) plan for $150/month. This plan provides ample speed for 4K streaming, content creation, and multiple device usage.
# * **Plan 2:** 750 Mbps plan for $120/month. This plan is a more budget-friendly option that still supports 4K streaming and content creation, but with slightly lower speeds.
#
# **Add-on Services:**
#
# * **Whole-Home WiFi System:** To ensure strong WiFi coverage throughout the multi-story house, I recommend adding a Whole-Home WiFi System. This system typically includes a main router and multiple access points that work together to provide seamless coverage. Cost: $10-20/month.
# * **Advanced Parental Controls:** To meet the customer's requirement for flexible parental controls, I suggest adding an advanced parental control feature. This feature allows for custom user profiles, time limits, and content filtering. Cost: $5-10/month.
# * **Multi-User Profile Management:** To support multiple user profiles, I recommend adding a feature that allows for easy management of user profiles and device assignments. Cost: $5-10/month.
# * **Easy-to-Use Interface:** To meet the customer's requirement for an easy-to-use interface, I suggest adding a user-friendly portal that allows for simple management of internet settings, parental controls, and device assignments. Cost: included with the internet plan.
#
# **Additional Recommendations:**
#
# * **Quality of Service (QoS) Settings:** To ensure that critical applications like 4K streaming and content creation receive sufficient bandwidth, I recommend configuring QoS settings. This can be done through the advanced settings of the router or with the help of our technical support team.
# * **Regular Speed Tests:** To ensure that the customer is receiving the expected speeds, I recommend conducting regular speed tests. This can be done through our online portal or with the help of our technical support team.
#
# **Total Cost:**
# The total cost for the recommended internet plan and add-on services would be:
#
# * **Plan 1:** $150 (internet) + $10 (Whole-Home WiFi) + $5 (Advanced Parental Controls) + $5 (Multi-User Profile Management) = $170/month
# * **Plan 2:** $120 (internet) + $10 (Whole-Home WiFi) + $5 (Advanced Parental Controls) + $5 (Multi-User Profile Management) = $140/month
#
# Both plans are within the customer's budget of $100-200/month.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 9:
# Customer Profile:
#         - Usage: Esports and professional streaming
#         - Devices: Workstations, Servers, Multiple monitors, Professional equipment
#         - Location: 3-bedroom house
#         - Budget: No budget constraints
#
# Additional Requirements:
# - Ultra-low latency
# - Quality of Service (QoS)
# - Traffic prioritization
# - Performance monitoring
#
# Analyzing scenario...
#
# Recommendations:
# Based on the customer scenario, I would recommend the following internet plan and add-on services to meet their specific needs:
#
# **Internet Plan:**
#
# * **Fiber-Optic Internet**: Due to the customer's requirement for ultra-low latency and high-bandwidth applications such as esports and professional streaming, a fiber-optic internet connection is the best option. This type of connection provides symmetrical upload and download speeds, which is ideal for applications that require high-speed uploads.
# * **Speed Tier:** 10 Gbps (10,000 Mbps) - This speed tier will provide more than enough bandwidth to support the customer's workstations, servers, multiple monitors, and professional equipment.
# * **Static IP:** Include a static IP address to ensure that the customer's servers and equipment have a fixed IP address, which is essential for professional applications.
#
# **Add-on Services:**
#
# * **Quality of Service (QoS)**: Implement QoS to prioritize traffic and ensure that critical applications receive sufficient bandwidth. This will help to prevent congestion and ensure that the customer's professional applications receive the necessary resources.
# * **Traffic Shaping**: Offer traffic shaping to further optimize bandwidth allocation and prioritize critical applications.
# * **Performance Monitoring**: Provide 24/7 performance monitoring to ensure that the internet connection is running at optimal levels. This will help to identify and resolve any issues promptly.
# * **Dedicated Support**: Offer dedicated support to ensure that the customer receives priority assistance in case of any issues or concerns.
# * **Wireless Network Optimization**: Although the customer doesn't have WiFi issues currently, it's essential to ensure that the wireless network is optimized to support the multiple devices. Provide a wireless network optimization service to ensure that the WiFi network is running at optimal levels.
#
# **Additional Recommendations:**
#
# * **Redundant Internet Connection**: Consider offering a redundant internet connection to ensure that the customer's business remains operational in case of an outage.
# * **Network Security**: Offer network security services to protect the customer's network from cyber threats and ensure that their professional equipment is secure.
#
# **Similar Customer Patterns Analysis:**
#
# * The average devices per customer (12.4) is higher than the typical household, which indicates that these customers require more advanced internet solutions to support their devices.
# * The average download speed of 1.0 Mbps is relatively low, which suggests that these customers may require more bandwidth-intensive applications.
# * The low number of customers with WiFi issues (1) indicates that the current WiFi solutions are generally effective, but it's essential to continue monitoring and optimizing the wireless network to ensure optimal performance.
#
# By recommending a fiber-optic internet plan with a high-speed tier, static IP, and add-on services such as QoS, traffic shaping, and performance monitoring, we can ensure that the customer's professional applications receive the necessary resources to operate at optimal levels.
# ================================================================================
#
# Processing next scenario in 2 seconds...
#
# ================================================================================
# Scenario 10:
# Customer Profile:
#         - Usage: 4K streaming and content creation
#         - Devices: Multiple smartphones, Gaming PC, Smart TVs, Tablets
#         - Location: 3-bedroom house
#         - Budget: $100-200/month
#
# Additional Requirements:
# - Camera system support
# - Continuous monitoring
# - Backup connection
# - Security features
#
# Analyzing scenario...
#
# Recommendations:
# Based on the provided customer scenario, I recommend the following internet plan and add-on services to meet their requirements:
#
# **Internet Plan:**
#
# * **Speed:** 500 Mbps to 1 Gbps (gigabit) download speed to support 4K streaming, content creation, and multiple devices.
# * **Type:** Fiber-optic or cable internet for reliable and fast connectivity.
#
# **Recommended Plans:**
#
# 1. **Plan 1:** 500 Mbps fiber-optic internet with a monthly data cap of 2 TB (Terabytes) for $120/month.
# 2. **Plan 2:** 1 Gbps cable internet with a monthly data cap of 3 TB for $180/month.
#
# **Add-on Services:**
#
# 1. **Camera System Support:** Offer a smart home package that includes a camera system with continuous monitoring, motion detection, and alerts. This can be added for $20-$30/month.
# 2. **Continuous Monitoring:** Provide a 24/7 network monitoring service to ensure the customer's internet connection is always stable and secure. This can be included in the internet plan or added for $10-$20/month.
# 3. **Backup Connection:** Offer a 4G LTE or 5G mobile hotspot as a backup connection in case of internet outages. This can be added for $20-$50/month, depending on the data allowance.
# 4. **Security Features:** Include a comprehensive security suite with features like antivirus software, firewall protection, and parental controls. This can be added for $10-$20/month.
#
# **Additional Recommendations:**
#
# 1. **Mesh Wi-Fi System:** Offer a mesh Wi-Fi system to ensure whole-home coverage and reliable connectivity. This can be added for $100-$200, depending on the number of nodes required.
# 2. **Quality of Service (QoS):** Provide QoS settings to prioritize traffic for critical applications like 4K streaming and online gaming.
# 3. **Device Protection:** Offer device protection services like antivirus software and data backup solutions to safeguard the customer's devices.
#
# **Example Packages:**
#
# 1. **Premium Package:** 1 Gbps cable internet, smart home package, 24/7 network monitoring, 4G LTE mobile hotspot, security suite, and mesh Wi-Fi system for $200/month.
# 2. **Deluxe Package:** 500 Mbps fiber-optic internet, camera system support, continuous monitoring, security suite, and device protection services for $150/month.
#
# These packages cater to the customer's needs and provide a comprehensive solution for their internet and security requirements.
# ================================================================================
#
# Testing completed!
